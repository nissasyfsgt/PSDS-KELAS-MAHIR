# %% [markdown]
# <a href="https://colab.research.google.com/github/nissasyfsgt/PSDS-KELAS-MAHIR/blob/main/1800015039_Nissa_Syifa_Yuni_Sagita(Model_Regresi_Linear_dengan_OLS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Model Regresi Linear dengan OLS**

# %% [markdown]
# ## **Model Regresi Linear Sederhana**

# %% [markdown]
# Regresi Linear adalah metode untuk mendefinisikan hubungan linear antara variabel dependen **$Y$** dan variabel independen **$X$**.
#
# Secara sederhana dapat dituliskan dalam formula berikut:
#
# $$Y_i=b_0+b_1X_i+\epsilon_{i}$$
#
# Yang mana *$Y_i$* adalah variabel dependen, *$X_i$* adalah variabel independen, *$\epsilon$* adalah kesalahan acak, *$b_0$* disebut sebagai intercept dan *$b_1$* disebut sebagai koefisien regresi yang dapat diestimasi berdasarkan data *$Y_i$* dan *$X_i$* yang diberikan. Koefisien *$b_0$* juga biasa disebut sebagai bias. Tujuan utama dari model ini adalah untuk mengambarkan garis linear dengan kesesuaian terbaik (*best fit*) antara $X$ dan $Y$ yang mengestimasi hubungan antara $X$ dan $Y$.
#
# Lalu bagaimana untuk mengestimasi koefisien tersebut? Salah satu pendekatan yang dapat dilakukan adalah menggunakan metode **Ordinary Least Mean Square Method**. Pada python notebook ini, kita akan mengimplementasikan metode Ordinary Least Mean Square Method.

# %% [markdown]
# ## **Ordinary Least Mean Square**

# %% [markdown]
# Sebelumnya kita telah membahas tentang estimasi hubungan antara X dan Y pada sebuah garis. Misalnya, kita sediakan input dan output sampel, kemudian kita memplot titik titik data ini pada grafik 2 dimensi, maka akan dihasilkan grafik seperti di bawah ini:
#
# ![Data Regresi.png](data:image/png;base64,...)
#
# Garis merah pada grafik adalah hubungan sesungguhnya yang ingin disetimasi. Kita berusaha untuk meminimalkan kesalahan model yang kita bangun. Garis ini adalah garis yang paling tepat menggambarkan
# hubungan antara data $X$ dan $Y$ dengan melewati sebagian besar titik data dan memiliki kesalahan yang paling minimal. Kesalahan ini berupa jarak titik data ke garis estimasi model ini. Secara konseptual kesalahan ini diilustrasikan pada gambar di bawah ini.
#
# ![LS.gif](data:image/gif;base64,...)

# %% [markdown]
# Dan kesalahan total model linier adalah jumlah kesalahan dari setiap titiknya, yaitu:
#
# ![Screenshot (26).png](data:image/png;base64,...)
#
#
# *$є_i$* = Jarak antara garis ke titik data ke-i
#
# *$n$* = Jumlah total titik data
#
# Formula di atas diperoleh dari:
#
# ![Screenshot (36).png](data:image/png;base64,...)
#
# Pada baris terakhir persamaan di atas kita mengkuadratkan kesalahan yang berupa jarak antara garis estimasi dengan titik data. Kita dapat mengkuadratkan masing-masing jarak karena terdapat beberapa titik di atas garis dan beberapa di bawahnya. Kemudian, untuk memperoleh model terbaik jarak tersebut dapat kita minimumkan. Misal ![Screenshot (49).png](data:image/png;base64,...)

# %% [markdown]
# Ide Dasar Metode OLS: **Nilai minimum dari fungsi kesalahan** ![Screenshot (50).png](data:image/png;base64,...)  **terjadi saat turunan pertama terhadap koefisien $b_0$ dan $b_1$ sama dengan 0. Ini merujuk pada konsep dasar turunan fungsi dalam kalkulus yaitu nilai minimum suatu fungsi terjadi saat turunan pertamanya sama dengan 0**
#
# Konsep ini kemudian diperluas menjadi metode Gradient Descent.

# %% [markdown]
# **Mencari nilai minimum untuk $b_0$**
#
# ![Screenshot (37).png](data:image/png;base64,...)
#
# Sehingga diperoleh formula untuk $𝑏_0$ adalah
#
# ![Screenshot (38).png](data:image/png;base64,...)

# %% [markdown]
# **Mencari nilai minimum untuk $𝑏_1$**
#
# ![Screenshot (39).png](data:image/png;base64,...)
#
# Sehingga diperoleh formula untuk $𝑏_1$ adalah
#
# ![Screenshot (40).png](data:image/png;base64,...)
#
# Persamaan terakhir bisa ditulis ulang untuk kemudahan pemrograman sebagai berikut:
# ![Screenshot (41).png](data:image/png;base64,...)
#
# Setelah mendapatkan keduanya, kita dapat mulai melakukan implementasi pada python.

# %% [markdown]
# **##Contoh Perhitungan Manual Regresi Linear dengan OLS**
#
# Diketahui data X dan Y adalah sebagai berikut(Y=2X-1):
#
# ![Screenshot (42).png](data:image/png;base64,...)

# %% [markdown]
# Berikut adalah proses menghitung model Regresi Linear dari data di atas:
#
# 1. Menghitung rata-rata X dan Y
# ![Screenshot (43).png](data:image/png;base64,...)

# %% [markdown]
# 2. Menghitung $b_1$
#
# ![Screenshot (44).png](data:image/png;base64,...)

# %% [markdown]
# 3. Menghitung $b_0$
# ![Screenshot (45).png](data:image/png;base64,...)

# %% [markdown]
# 4. Menyusun Persamaan Regresi Linear
#
# ![Screenshot (46).png](data:image/png;base64,...)

# %% [markdown]
# ##Regresi Linear Python From Scratch
#
# ###Membangun Model Regresi Linear
#
# pertama, import library python yang dibutuhkan yaitu:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Untuk memahami konsep, kita akan menggunakan data X dan Y seperti yang kita tunjukkan pada proses
# penghitungan manual.

# %%
X_train=np.array([1, 3, 5, 6, 7, 8])
y_train=np.array([1, 5, 9, 11, 13, 15])

# %%
# Proses Training Model

# Menghitung rata-rata inputs and outputs
x_rata2 = np.mean(X_train)
print("Rata-rata X:", x_rata2)
y_rata2 = np.mean(y_train)
print("Rata-rata Y:", y_rata2)

# Jumlah data
n = len(X_train)
print("Jumlah data(n):", y_rata2)
# Menuliskan formula untuk menghitung beta 0 dan beta 1
A = 0
B = 0
for i in range(n):
  a = (X_train[i] - x_rata2) * (y_train[i] - y_rata2)
  print("(",X_train[i], "-", x_rata2, ")", "*", "(", y_train[i], "-", y_rata2, ") =", a )
  A += a
  b = (X_train[i] - x_rata2) ** 2
  print("(", X_train[i], "-", x_rata2, ")", "^2", " =", b )
  B += b
print("Pembilang =", A)
print("Penyebut =", B)

# Menampilkan Koefisien Regresi Linear
b_1 = A / B
print("b_1 =", b_1)
b_0 = y_rata2 - (b_1 * x_rata2)
print("b_0 =", b_0)
# Out:
# Rata-rata X: 5.0
# Rata-rata Y: 9.0
# Jumlah data(n): 9.0
# ( 1 - 5.0 ) * ( 1 - 9.0 ) = 32.0
# ( 1 - 5.0 ) ^2  = 16.0
# ( 3 - 5.0 ) * ( 5 - 9.0 ) = 8.0
# ( 3 - 5.0 ) ^2  = 4.0
# ( 5 - 5.0 ) * ( 9 - 9.0 ) = 0.0
# ( 5 - 5.0 ) ^2  = 0.0
# ( 6 - 5.0 ) * ( 11 - 9.0 ) = 2.0
# ( 6 - 5.0 ) ^2  = 1.0
# ( 7 - 5.0 ) * ( 13 - 9.0 ) = 8.0
# ( 7 - 5.0 ) ^2  = 4.0
# ( 8 - 5.0 ) * ( 15 - 9.0 ) = 18.0
# ( 8 - 5.0 ) ^2  = 9.0
# Pembilang = 68.0
# Penyebut = 34.0
# b_1 = 2.0
# b_0 = -1.0

# %%
# Plot Nilai Data
x_max = np.max(X_train)
x_min = np.min(X_train)

# Garis Regresi
x = np.linspace(x_min, x_max, 1000)
y = b_0 + b_1 * x

# Plott Garis Regresi
plt.plot(x, y, color='red', label='Regresi Linear')

# Plot Titik Data
plt.scatter(X_train, y_train, color='blue', label='Data')

# Label sumbu
plt.xlabel('X')

# Label sumbu y
plt.ylabel('Y')

# Menampilkan Legenda
plt.legend()

# Menampilkan Gambar Hasil Plot
plt.show()

# %% [markdown]
# ###Implementasi Model Regresi Linear Pada Data Real
#
# Kita akan menggunakan dataset yang berisi **ukuran kepala** dan **berat organ otak**.

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/nissasyfsgt/DATASET/main/Daftar_gaji.csv')

# Melihat ukuran dataset
print(dataset.shape)

# Menampilkan 5 data teratas
dataset.head()
# Out:
# (30, 2)
#    Tahun_bekerja     Gaji
# 0            1.1  39343.0
# 1            1.3  46205.0
# 2            1.5  37731.0
# 3            2.0  43525.0
# 4            2.2  39891.0

# %% [markdown]
# Mencari hubungan antara data X(Tahun Bekerja) dan Y(Gaji)

# %%
# Definisikan Variabel Input(X) dan Output(Y)
X = dataset['Tahun_bekerja'].values.reshape(-1,1)
Y = dataset['Gaji'].values.reshape(-1,1)

# %%
# Membagi data menjadi data training dan data testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Proses Training Model

# Menghitung rata-rata inputs and outputs
x_rata2 = np.mean(X_train)
y_rata2 = np.mean(y_train)

# Jumlah data
n = len(X_train)

# Menuliskan formula untuk menghitung beta 0 dan beta 1
A = 0
B = 0
for i in range(n):
  A += (X_train[i] - x_rata2) * (y_train[i] - y_rata2)
  B += (X_train[i] - x_rata2) ** 2

b_1 = A / B
b_0 = y_rata2 - (b_1 * x_rata2)

# %% [markdown]
# Dalam notasi matematika, hasil ini dapat ditulis sebagai berikut:
#
#     Brain weights = 334.26127335 + 0.26106902 * Head size
#
# Sekarang kita memiliki model linier. Mari kita plot secara grafis.

# %%
# Plot Nilai Data
x_max = np.max(X) + 10
x_min = np.min(X) - 10

# Garis Regresi
x = np.linspace(x_min, x_max, 1000)
y = b_0 + b_1 * x

# Plott Garis Regresi
plt.plot(x, y, color='red', label='Regresi Linear')

# Plot Titik Data
plt.scatter(X, Y, color='blue', label='Data')

# Label sumbu
plt.xlabel('Tahun Bekerja')

# Label sumbu y
plt.ylabel('Gaji')

# Menampilkan Legenda
plt.legend()

# Menampilkan Gambar Hasil Plot
plt.show()

# %% [markdown]
# ###Evaluasi Model
#
# Kita perlu mengukur tingkat ketepatan(akurasi) model yang telah diperoleh. Terdapat banyak metode untuk melakukan hal ini, namun pada artikel ini kita memilih menggunakan **Root Mean Square Error dan Koefisien Determinasi ($𝑅^2$ Skor)**
#
# ![Screenshot (52).png](data:image/png;base64,...)

# %% [markdown]
# $𝑦^_𝑖$ adalah nilai hasil prediksi ke-i. Berikut adalah penulisan kode untuk RMSE

# %%
rmse = 0
for i in range(len(X_test)):
  y_pred= b_0 + b_1* X_test[i]
  rmse += (y_test[i] - y_pred) ** 2
rmse = np.sqrt(rmse/n)
print(rmse)
# Out:
# [1790.48961866]

# %% [markdown]
# Selanjutnya, mari kita hitung nilai $R^2$ skor untuk mengukur tingkat akurasi dari model linear yang diperoleh, secara matematis $R^2$ dituliskan sebagai berikut:
#
# ![Screenshot (54).png](data:image/png;base64,...)
#
# SSE adalah jumlah kuadrat galat sedangkan SST jumlah kuadrat total.
#
# $R^2$ skor biasanya memiliki nilai antara 0 hingga 1. Nilai ini juga bisa bernilai negatif jika model regresi benar-benar salah. Di bawah ini adalah kode pemrograman untuk menghitung $R^2$ skor

# %%
SST = 0
SSE = 0
y_pred= b_0 + b_1*X_test
y_rata2 = np.mean(y_test)
for i in range(len(X_test)) :
  SST += (y_test[i] - y_rata2) ** 2
  SSE += (y_test[i] - y_pred[i]) **2

score = 1- (SSE/SST)
print("Koefisien Determinasi:", score)
# Out:
# Koefisien Determinasi: [0.98816952]
